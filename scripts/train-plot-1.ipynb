# %%
import csv
import matplotlib.pyplot as plt

# %%
import pandas as pd
df = pd.read_csv('logs/train/sac-230620195940.csv')
print(df.head())
# Out:
#    Episode  Time steps  Episode Rewards  Average Rewards  Epsilon   Elapsed
# 0        1           9         7.097486         0.788610      0.0  1.119630  \
# 1        2          13        10.664362         0.820336      0.0  0.942135
# 2        3          24        21.782645         0.907610      0.0  1.627818
# 3        4           5         4.500290         0.900058      0.0  0.327679
# 4        5          15        12.646784         0.843119      0.0  0.985819
#
#    Total Elapsed
# 0       1.119630
# 1       2.068753
# 2       3.696571
# 3       4.024250
# 4       5.010069

# %%
df['Average Rewards'].plot()
# Out:
# <Axes: >
