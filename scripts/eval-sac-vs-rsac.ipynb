# %%
import matplotlib.pyplot as plt
import pandas as pd
from enum import Enum

class OCCLUSION(Enum):
    Low = 1
    Medium = 2
    High = 3

# %%
def get_test_log_df(model_type: str, model_id, test_id, occlusion):
    if isinstance(occlusion, OCCLUSION):
        occlusion = occlusion._value_
    base_path = '../../data/logs/test'
    log_path = f'{base_path}/{model_type}-{model_id}/{test_id}-{occlusion}.csv'
    df = pd.read_csv(log_path)
    return df

# %% [markdown]
# ---
# ### Load Evaluation Logs

# %%
# Baseline
model_type = 'sac_v2'
model_id = '230704203226'
test_id = '230708214325'

baseline = {}
for occlusion in OCCLUSION:
    baseline[occlusion] = get_test_log_df(model_type, model_id, test_id, occlusion)

# %%
# Compare
model_type = 'sac_v2_lstm'
model_id = '230706072839'
test_id = '230708102319'

model = {}
for occlusion in OCCLUSION:
    model[occlusion] = get_test_log_df(model_type, model_id, test_id, occlusion)

# %% [markdown]
# ---
# Collision Success Rate

# %%
for df, key in ((baseline[key], key) for key in baseline):
    # Number of pedestrians crossed for each episode
    series = df.groupby(['episode'])['pedestrian_crossed'].max()
    print(f'Baseline {key}: Max {series.max()}, Min {series.min()}, Average {series.mean()}')
# Out:
# Baseline OCCLUSION.Low: Max 36, Min 0, Average 7.46
# Baseline OCCLUSION.Medium: Max 25, Min 0, Average 4.56
# Baseline OCCLUSION.High: Max 21, Min 0, Average 3.92

# %%
#for df, key in ((baseline[key], key) for key in baseline):
#    # Number of pedestrians crossed for each episode
#    series = df[df['pedestrian_crossed'] != 0].groupby(['episode'])['pedestrian_crossed'].max()
#    print(f'Model {key}: Max {series.max()}, Min {series.min()}, Average {series.mean()}')

# %%
for df, key in ((baseline[key], key) for key in baseline):
    # Number of pedestrians crossed for each episode
    series = df.groupby(['episode'])['pedestrian_crossed'].max()
    print(f'Baseline {key}:')
    print(series)
# Out:
# Baseline OCCLUSION.Low:
# episode
# 0      0
# 1      0
# 2      0
# 3      0
# 4     29
# 5      0
# 6      0
# 7      0
# 8      2
# 9      6
# 10     2
# 11     6
# 12     0
# 13     0
# 14    26
# 15     3
# 16    20
# 17     5
# 18    17
# 19     5
# 20     0
# 21     2
# 22     3
# 23     0
# 24    30
# 25    11
# 26    24
# 27     7
# 28    12
# 29     6
# 30     6
# 31    15
# 32     0
# 33    11
# 34     1
# 35    16
# 36     2
# 37    36
# 38     9
# 39    24
# 40     5
# 41     1
# 42     3
# 43    13
# 44     0
# 45     2
# 46     4
# 47     7
# 48     0
# 49     2
# Name: pedestrian_crossed, dtype: int64
# Baseline OCCLUSION.Medium:
# episode
# 0      0
# 1     10
# 2      2
# 3     17
# 4      0
# 5      7
# 6      6
# 7      1
# 8      3
# 9      0
# 10    15
# 11     0
# 12     3
# 13     2
# 14     4
# 15     0
# 16     7
# 17     0
# 18     0
# 19     0
# 20    25
# 21     1
# 22     0
# 23     5
# 24     0
# 25    12
# 26     7
# 27     0
# 28     2
# 29     1
# ...

# %%
for df, key in ((model[key], key) for key in model):
    # Number of pedestrians crossed for each episode
    series = df.groupby(['episode'])['pedestrian_crossed'].max()
    print(f'Model {key}: Max {series.max()}, Min {series.min()}, Average {series.mean()}')
# Out:
# Model OCCLUSION.Low: Max 40, Min 0, Average 24.54
# Model OCCLUSION.Medium: Max 40, Min 0, Average 16.82
# Model OCCLUSION.High: Max 40, Min 0, Average 13.38

# %%
#for df, key in ((model[key], key) for key in model):
#    # Number of pedestrians crossed for each episode
#    series = df[df['pedestrian_crossed'] != 0].groupby(['episode'])['pedestrian_crossed'].max()
#    print(f'Model {key}: Max {series.max()}, Min {series.min()}, Average {series.mean()}')

# %%
for df, key in ((model[key], key) for key in model):
    # Number of pedestrians crossed for each episode
    series = df.groupby(['episode'])['pedestrian_crossed'].max()
    print(f'Model {key}:')
    print(series)
# Out:
# Model OCCLUSION.Low:
# episode
# 0     35
# 1     34
# 2      0
# 3     39
# 4     37
# 5     37
# 6     34
# 7      0
# 8      0
# 9     36
# 10    34
# 11     0
# 12     0
# 13    39
# 14    38
# 15     0
# 16    25
# 17    36
# 18    35
# 19     0
# 20    37
# 21     2
# 22    35
# 23    29
# 24    38
# 25     0
# 26    37
# 27    36
# 28    39
# 29    35
# 30    35
# 31     0
# 32    38
# 33     0
# 34    36
# 35     0
# 36     0
# 37    36
# 38    33
# 39    38
# 40    33
# 41    38
# 42     0
# 43     0
# 44    38
# 45     0
# 46    38
# 47    37
# 48    40
# 49    40
# Name: pedestrian_crossed, dtype: int64
# Model OCCLUSION.Medium:
# episode
# 0      0
# 1     35
# 2     37
# 3      6
# 4     10
# 5      0
# 6      0
# 7     40
# 8     38
# 9     33
# 10    36
# 11    31
# 12     1
# 13     0
# 14    38
# 15    10
# 16    36
# 17     0
# 18    36
# 19    36
# 20    31
# 21    22
# 22     7
# 23    37
# 24     0
# 25    40
# 26     0
# 27    19
# 28     0
# 29     0
# ...

# %% [markdown]
# ---
# Average Reward Value

# %%
for df, key in ((baseline[key], key) for key in baseline):
    series = df.groupby(['episode'])['reward']
    # Across all episodes
    print(f'Baseline {key} all episodes: Max {series.max().max()}, Min {series.min().min()}, Average {series.mean().mean()}')
# Out:
# Baseline OCCLUSION.Low all episodes: Max 0.9436071831014524, Min -1.0, Average 0.6245777105642611
# Baseline OCCLUSION.Medium all episodes: Max 0.9464316579366672, Min -1.0, Average 0.6500125441969316
# Baseline OCCLUSION.High all episodes: Max 0.9435148901450132, Min -1.0, Average 0.6644585565167318

# %%
for df, key in ((model[key], key) for key in model):
    series = df.groupby(['episode'])['reward']
    # Across all episodes
    print(f'Model {key} all episodes: Max {series.max().max()}, Min {series.min().min()}, Average {series.mean().mean()}')
# Out:
# Model OCCLUSION.Low all episodes: Max 0.9361854604125666, Min -1.0, Average 0.6795652901697161
# Model OCCLUSION.Medium all episodes: Max 0.9342547678116684, Min -1.0, Average 0.7034069820459803
# Model OCCLUSION.High all episodes: Max 0.9397995054270344, Min -1.0, Average 0.7206723070672707

# %%
for df, key in ((baseline[key], key) for key in baseline):
    series = df.groupby(['episode'])['reward']
    print(f'Baseline {key}')
    print(series.mean()) # Average of each episode
# Out:
# Baseline OCCLUSION.Low
# episode
# 0     0.625134
# 1     0.545249
# 2     0.649076
# 3     0.696324
# 4     0.612887
# 5     0.615837
# 6     0.672110
# 7     0.589523
# 8     0.695648
# 9     0.608755
# 10    0.653874
# 11    0.536655
# 12    0.653552
# 13    0.477834
# 14    0.625297
# 15    0.614626
# 16    0.626304
# 17    0.632152
# 18    0.624029
# 19    0.624349
# 20    0.632735
# 21    0.669109
# 22    0.577052
# 23    0.650271
# 24    0.616863
# 25    0.627599
# 26    0.637364
# 27    0.621517
# 28    0.596858
# 29    0.630007
# 30    0.635245
# 31    0.607687
# 32    0.621855
# 33    0.632800
# 34    0.574259
# 35    0.632705
# 36    0.591135
# 37    0.649878
# 38    0.660320
# 39    0.639257
# 40    0.662421
# 41    0.646194
# 42    0.612731
# 43    0.650279
# 44    0.634133
# 45    0.626191
# 46    0.629858
# 47    0.616225
# 48    0.601909
# 49    0.665216
# Name: reward, dtype: float64
# Baseline OCCLUSION.Medium
# episode
# 0     0.663702
# 1     0.661171
# ...

# %%
for df, key in ((model[key], key) for key in model):
    series = df.groupby(['episode'])['reward']
    print(f'Model {key}')
    print(series.mean()) # Average of each episode
# Out:
# Model OCCLUSION.Low
# episode
# 0     0.662009
# 1     0.667329
# 2     0.704787
# 3     0.656101
# 4     0.670718
# 5     0.631295
# 6     0.665461
# 7     0.725729
# 8     0.709983
# 9     0.657788
# 10    0.667140
# 11    0.685929
# 12    0.728468
# 13    0.648536
# 14    0.675057
# 15    0.743920
# 16    0.622799
# 17    0.666177
# 18    0.672865
# 19    0.733566
# 20    0.667788
# 21    0.721402
# 22    0.645488
# 23    0.663454
# 24    0.661443
# 25    0.682666
# 26    0.660296
# 27    0.675979
# 28    0.668318
# 29    0.662772
# 30    0.664269
# 31    0.741390
# 32    0.634922
# 33    0.702651
# 34    0.676686
# 35    0.747726
# 36    0.751230
# 37    0.680382
# 38    0.658814
# 39    0.662171
# 40    0.650916
# 41    0.661549
# 42    0.739705
# 43    0.682928
# 44    0.659788
# 45    0.694644
# 46    0.659478
# 47    0.670475
# 48    0.664451
# 49    0.668828
# Name: reward, dtype: float64
# Model OCCLUSION.Medium
# episode
# 0     0.723128
# 1     0.682034
# 2     0.679555
# ...

# %%
plt.figure(figsize=(8,2))
baseline[OCCLUSION.Low].groupby(['episode'])['reward'].max().plot(label='SAC', linestyle='dashed')
model[OCCLUSION.Low].groupby(['episode'])['reward'].max().plot(label='RSAC')
plt.title('Avg Reward (Low Occlusion Level)')
plt.xlabel('Episode')
plt.ylabel('Avg Reward')
plt.legend(loc='lower right')

print(baseline[OCCLUSION.Low].groupby(['episode'])['reward'].max().std())
print(model[OCCLUSION.Low].groupby(['episode'])['reward'].max().std())
# Out:
# 0.01936727367003015
# 0.007283907564498436

# %%
plt.figure(figsize=(8,2))
baseline[OCCLUSION.Medium].groupby(['episode'])['reward'].max().plot(label='SAC', linestyle='dashed')
model[OCCLUSION.Medium].groupby(['episode'])['reward'].max().plot(label='RSAC')
plt.title('Avg Reward (Medium Occlusion Level)')
plt.xlabel('Episode')
plt.ylabel('Avg Reward')
plt.legend(loc='lower right')

print(baseline[OCCLUSION.Medium].groupby(['episode'])['reward'].max().std())
print(model[OCCLUSION.Medium].groupby(['episode'])['reward'].max().std())
# Out:
# 0.0157000389818884
# 0.006167037122032643

# %%
plt.figure(figsize=(8,2))
baseline[OCCLUSION.High].groupby(['episode'])['reward'].max().plot(label='SAC', linestyle='dashed')
model[OCCLUSION.High].groupby(['episode'])['reward'].max().plot(label='RSAC')
plt.title('Avg Reward (High Occlusion Level)')
plt.xlabel('Episode')
plt.ylabel('Avg Reward')
plt.legend(loc='lower right')

print(baseline[OCCLUSION.High].groupby(['episode'])['reward'].max().std())
print(model[OCCLUSION.High].groupby(['episode'])['reward'].max().std())
# Out:
# 0.021360043714415897
# 0.005670204882523025

# %% [markdown]
# ---
# Episode Length

# %%
for df, key in ((baseline[key], key) for key in baseline):
    series = df.groupby(['episode'])['step'].max()
    # Across all episodes
    print(f'Baseline {key} all episodes: Max {series.max()}, Min {series.min()}, Average {series.mean()}')
# Out:
# Baseline OCCLUSION.Low all episodes: Max 222, Min 11, Average 68.78
# Baseline OCCLUSION.Medium all episodes: Max 204, Min 10, Average 52.1
# Baseline OCCLUSION.High all episodes: Max 167, Min 14, Average 50.94

# %%
for df, key in ((model[key], key) for key in model):
    series = df.groupby(['episode'])['step'].max()
    # Across all episodes
    print(f'Model {key} all episodes: Max {series.max()}, Min {series.min()}, Average {series.mean()}')
# Out:
# Model OCCLUSION.Low all episodes: Max 183, Min 14, Average 124.12
# Model OCCLUSION.Medium all episodes: Max 194, Min 13, Average 96.84
# Model OCCLUSION.High all episodes: Max 204, Min 15, Average 85.88

# %%
for df, key in ((baseline[key], key) for key in baseline):
    df_temp = df[df['completed'] == True]['step']
    print(f'Baseline Completion Step: Max {df_temp.max()}, Min {df_temp.min()}, Avg {df_temp.mean()}')

    df_temp = df[df['collided'] == True]['step']
    print(f'Baseline Collision Step: Max {df_temp.max()}, Min {df_temp.min()}, Avg {df_temp.mean()}')
    print()
# Out:
# Baseline Completion Step: Max 222, Min 222, Avg 222.0
# Baseline Collision Step: Max 192, Min 11, Avg 63.31707317073171
#
# Baseline Completion Step: Max nan, Min nan, Avg nan
# Baseline Collision Step: Max 135, Min 10, Avg 48.9375
#
# Baseline Completion Step: Max nan, Min nan, Avg nan
# Baseline Collision Step: Max 167, Min 14, Avg 51.5

# %%
for df, key in ((model[key], key) for key in model):
    df_temp = df[df['completed'] == True]['step']
    print(f'Model Completion Step: Max {df_temp.max()}, Min {df_temp.min()}, Avg {df_temp.mean()}')

    df_temp = df[df['collided'] == True]['step']
    print(f'Model Collision Step: Max {df_temp.max()}, Min {df_temp.min()}, Avg {df_temp.mean()}')
    print()
# Out:
# Model Completion Step: Max 183, Min 157, Avg 174.59375
# Model Collision Step: Max 152, Min 14, Avg 34.388888888888886
#
# Model Completion Step: Max 194, Min 173, Avg 185.10526315789474
# Model Collision Step: Max 187, Min 13, Avg 46.9375
#
# Model Completion Step: Max 204, Min 187, Avg 196.72727272727272
# Model Collision Step: Max 191, Min 15, Avg 54.61538461538461

# %%
# Completion
for df, key in ((baseline[key], key) for key in baseline):
    series = df[df['completed'] == True][['episode','step']]
    print(f'Baseline {key} Count: {series.count()}')
    print(series)
# Out:
# Baseline OCCLUSION.Low Count: episode    1
# step       1
# dtype: int64
#       episode  step
# 2665       37   222
# Baseline OCCLUSION.Medium Count: episode    0
# step       0
# dtype: int64
# Empty DataFrame
# Columns: [episode, step]
# Index: []
# Baseline OCCLUSION.High Count: episode    0
# step       0
# dtype: int64
# Empty DataFrame
# Columns: [episode, step]
# Index: []

# %%
for df, key in ((model[key], key) for key in model):
    series = df[df['completed'] == True][['episode','step']]
    print(f'Baseline {key} Count: {series.count()}')
    print(series)
# Out:
# Baseline OCCLUSION.Low Count: episode    32
# step       32
# dtype: int64
#       episode  step
# 173         0   173
# 348         1   174
# 540         3   173
# 718         4   177
# 882         5   163
# 1064        6   181
# 1271        9   168
# 1442       10   170
# 1658       13   171
# 1841       14   182
# 2158       17   181
# 2339       18   180
# 2536       20   177
# 2763       22   171
# 3092       24   175
# 3290       26   175
# 3473       27   182
# 3649       28   175
# 3826       29   176
# 4002       30   175
# 4177       32   157
# 4379       34   183
# 4614       37   183
# 4792       38   177
# 4976       39   183
# 5140       40   163
# 5314       41   173
# 5531       44   176
# 5731       46   172
# 5910       47   178
# 6084       48   173
# 6255       49   170
# Baseline OCCLUSION.Medium Count: episode    19
# step       19
# dtype: int64
#       episode  step
# 199         1   180
# 385         2   185
# 780         7   188
# 960         8   179
# ...

# %% [markdown]
# ---
# ## Qualitative

# %% [markdown]
# ---
# Speed Profile

# %%
series = baseline[OCCLUSION.Low].groupby('episode').max()
print(series[series['step'] == series['step'].max()]['step'])
# Out:
# episode
# 37    222
# Name: step, dtype: int64

# %%
_, axs = plt.subplots(nrows=4, figsize=(8, 8))
df = baseline[OCCLUSION.Low]
df = df[df['episode'] == 37]
df['speed'].plot(ax=axs[0], label='speed', c='C2').legend(loc='upper right')
df['heading'].plot(ax=axs[1], label='heading', c='C0').legend(loc='upper right')
df['observed_obstacles'].plot(ax=axs[2], label='observed obstacles', c='C1').legend(loc='upper right')
df['observed_pedestrians'].plot(ax=axs[3], label='observed pedestrians', c='C3').legend(loc='upper right')

# %%
df['speed'].plot(kind='hist', xlabel='speed')
# Out:
# <Axes: xlabel='speed', ylabel='Frequency'>

# %%
df[['speed', 'heading', 'observed_obstacles', 'observed_pedestrians']].corr(method='spearman')[['speed', 'heading']]
# Out:
#                          speed   heading
# speed                 1.000000 -0.046566
# heading              -0.046566  1.000000
# observed_obstacles    0.034504  0.199730
# observed_pedestrians  0.124035 -0.135535

# %%
series = baseline[OCCLUSION.Medium].groupby('episode').max()
print(series[series['step'] == series['step'].max()]['step'])
# Out:
# episode
# 20    204
# Name: step, dtype: int64

# %%
_, axs = plt.subplots(nrows=4, figsize=(8, 8))
df = baseline[OCCLUSION.Medium]
df = df[df['episode'] == 20]
df['speed'].plot(ax=axs[0], label='speed', c='C2').legend(loc='upper right')
df['heading'].plot(ax=axs[1], label='heading', c='C0').legend(loc='upper right')
df['observed_obstacles'].plot(ax=axs[2], label='observed obstacles', c='C1').legend(loc='upper right')
df['observed_pedestrians'].plot(ax=axs[3], label='observed pedestrians', c='C3').legend(loc='upper right')

# %%
df['speed'].plot(kind='hist', xlabel='speed')
# Out:
# <Axes: xlabel='speed', ylabel='Frequency'>

# %%
df[['speed', 'heading', 'observed_obstacles', 'observed_pedestrians']].corr(method='spearman')[['speed', 'heading']]
# Out:
#                          speed   heading
# speed                 1.000000 -0.143466
# heading              -0.143466  1.000000
# observed_obstacles   -0.086872  0.008652
# observed_pedestrians  0.209302  0.024725

# %%
series = baseline[OCCLUSION.High].groupby('episode').max()
print(series[series['step'] == series['step'].max()]['step'])
# Out:
# episode
# 2    167
# Name: step, dtype: int64

# %%
_, axs = plt.subplots(nrows=4, figsize=(8, 8))
df = baseline[OCCLUSION.High]
df = df[df['episode'] == 2]
df['speed'].plot(ax=axs[0], label='speed', c='C2').legend(loc='upper right')
df['heading'].plot(ax=axs[1], label='heading', c='C0').legend(loc='upper right')
df['observed_obstacles'].plot(ax=axs[2], label='observed obstacles', c='C1').legend(loc='upper right')
df['observed_pedestrians'].plot(ax=axs[3], label='observed pedestrians', c='C3').legend(loc='upper right')

# %%
df['speed'].plot(kind='hist', xlabel='speed')
# Out:
# <Axes: xlabel='speed', ylabel='Frequency'>

# %%
df[['speed', 'heading', 'observed_obstacles', 'observed_pedestrians']].corr(method='spearman')[['speed', 'heading']]
# Out:
#                          speed   heading
# speed                 1.000000 -0.162355
# heading              -0.162355  1.000000
# observed_obstacles   -0.000835 -0.050106
# observed_pedestrians  0.275300  0.038689

# %% [markdown]
# ---
# Evaluation Model

# %%
series = model[OCCLUSION.Low].groupby('episode').max()
print(series[series['step'] == series['step'].max()]['step'])
# Out:
# episode
# 34    183
# 37    183
# 39    183
# Name: step, dtype: int64

# %%
_, axs = plt.subplots(nrows=4, figsize=(8, 8))
df = model[OCCLUSION.Low]
df = df[df['episode'] == 37]
df['speed'].plot(ax=axs[0], label='speed', c='C2').legend(loc='upper right')
df['heading'].plot(ax=axs[1], label='heading', c='C0').legend(loc='upper right')
df['observed_obstacles'].plot(ax=axs[2], label='observed obstacles', c='C1').legend(loc='upper right')
df['observed_pedestrians'].plot(ax=axs[3], label='observed pedestrians', c='C3').legend(loc='upper right')

# %%
df['speed'].plot(kind='hist', xlabel='speed')
# Out:
# <Axes: xlabel='speed', ylabel='Frequency'>

# %%
df[['speed', 'heading', 'observed_obstacles', 'observed_pedestrians']].corr(method='spearman')[['speed', 'heading']]
# Out:
#                          speed   heading
# speed                 1.000000  0.058254
# heading               0.058254  1.000000
# observed_obstacles   -0.094422  0.144668
# observed_pedestrians  0.264542 -0.020076

# %%
series = model[OCCLUSION.Medium].groupby('episode').max()
print(series[series['step'] == series['step'].max()]['step'])
# Out:
# episode
# 19    194
# 20    194
# 40    194
# Name: step, dtype: int64

# %%
_, axs = plt.subplots(nrows=4, figsize=(8, 8))
df = model[OCCLUSION.Medium]
df = df[df['episode'] == 40]
df['speed'].plot(ax=axs[0], label='speed', c='C2').legend(loc='upper right')
df['heading'].plot(ax=axs[1], label='heading', c='C0').legend(loc='upper right')
df['observed_obstacles'].plot(ax=axs[2], label='observed obstacles', c='C1').legend(loc='upper right')
df['observed_pedestrians'].plot(ax=axs[3], label='observed pedestrians', c='C3').legend(loc='upper right')

# %%
df['speed'].plot(kind='hist', xlabel='speed')
# Out:
# <Axes: xlabel='speed', ylabel='Frequency'>

# %%
df[['speed', 'heading', 'observed_obstacles', 'observed_pedestrians']].corr(method='spearman')[['speed', 'heading']]
# Out:
#                          speed   heading
# speed                 1.000000  0.221148
# heading               0.221148  1.000000
# observed_obstacles    0.042130  0.042279
# observed_pedestrians  0.195158  0.015041

# %%
series = model[OCCLUSION.High].groupby('episode').max()
print(series[series['step'] == series['step'].max()]['step'])
# Out:
# episode
# 44    204
# Name: step, dtype: int64

# %%
_, axs = plt.subplots(nrows=4, figsize=(8, 8))
df = model[OCCLUSION.High]
df = df[df['episode'] == 44]
df['speed'].plot(ax=axs[0], label='speed', c='C2').legend(loc='upper right')
df['heading'].plot(ax=axs[1], label='heading', c='C0').legend(loc='upper right')
df['observed_obstacles'].plot(ax=axs[2], label='observed obstacles', c='C1').legend(loc='upper right')
df['observed_pedestrians'].plot(ax=axs[3], label='observed pedestrians', c='C3').legend(loc='upper right')

# %%
df['speed'].plot(kind='hist', xlabel='speed')
# Out:
# <Axes: xlabel='speed', ylabel='Frequency'>

# %%
df[['speed', 'heading', 'observed_obstacles', 'observed_pedestrians']].corr(method='spearman')[['speed', 'heading']]
# Out:
#                          speed   heading
# speed                 1.000000  0.113674
# heading               0.113674  1.000000
# observed_obstacles    0.368000  0.003749
# observed_pedestrians  0.192523  0.115578

# %% [markdown]
# ---
# Correleration

# %%
df = pd.concat(baseline, ignore_index=True)
df[['speed', 'heading', 'observed_obstacles', 'observed_pedestrians']].corr(method='spearman')
# Out:
#                          speed   heading  observed_obstacles
# speed                 1.000000 -0.069765           -0.000379  \
# heading              -0.069765  1.000000            0.002836
# observed_obstacles   -0.000379  0.002836            1.000000
# observed_pedestrians  0.094170  0.021179           -0.337614
#
#                       observed_pedestrians
# speed                             0.094170
# heading                           0.021179
# observed_obstacles               -0.337614
# observed_pedestrians              1.000000

# %%
df = pd.concat(model, ignore_index=True)
df[['speed', 'heading', 'observed_obstacles', 'observed_pedestrians']].corr(method='spearman')
# Out:
#                          speed   heading  observed_obstacles
# speed                 1.000000  0.062230           -0.161205  \
# heading               0.062230  1.000000            0.009612
# observed_obstacles   -0.161205  0.009612            1.000000
# observed_pedestrians  0.288283  0.045597           -0.267636
#
#                       observed_pedestrians
# speed                             0.288283
# heading                           0.045597
# observed_obstacles               -0.267636
# observed_pedestrians              1.000000
